# %%
#import Libraries
import pandas as pd

# %%
#read csv
df = pd.read_csv('train_blackFriday.csv')
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
#number of rows and coulmns
print(f'number of rows = {len(df)} and number of columns = {len(df.columns)}')
# Out:
# number of rows = 550068 and number of columns = 12

# %%
#show data types found
df.dtypes
# Out:
# User_ID                         int64
# Product_ID                     object
# Gender                         object
# Age                            object
# Occupation                      int64
# City_Category                  object
# Stay_In_Current_City_Years     object
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# Purchase                        int64
# dtype: object

# %%
#show coulmns
df.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
#Checking NaN values in the given dataset
df.isna()
# Out:
#         User_ID  Product_ID  Gender    Age  Occupation  City_Category  \
# 0         False       False   False  False       False          False
# 1         False       False   False  False       False          False
# 2         False       False   False  False       False          False
# 3         False       False   False  False       False          False
# 4         False       False   False  False       False          False
# ...         ...         ...     ...    ...         ...            ...
# 550063    False       False   False  False       False          False
# 550064    False       False   False  False       False          False
# 550065    False       False   False  False       False          False
# 550066    False       False   False  False       False          False
# 550067    False       False   False  False       False          False
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# ...

# %%
#Checking duplicate values in the dataset
# getting duplicated rows
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [User_ID, Product_ID, Gender, Age, Occupation, City_Category, Stay_In_Current_City_Years, Marital_Status, Product_Category_1, Product_Category_2, Product_Category_3, Purchase]
# Index: []

# %%
#Checking duplicate values in the dataset
# getting duplicated column values
df.apply(lambda x : x.duplicated())
# Out:
#         User_ID  Product_ID  Gender    Age  Occupation  City_Category  \
# 0         False       False   False  False       False          False
# 1          True       False    True   True        True           True
# 2          True       False    True   True        True           True
# 3          True       False    True   True        True           True
# 4         False       False   False  False       False          False
# ...         ...         ...     ...    ...         ...            ...
# 550063     True        True    True   True        True           True
# 550064     True        True    True   True        True           True
# 550065     True        True    True   True        True           True
# 550066     True        True    True   True        True           True
# 550067     True        True    True   True        True           True
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# ...

# %%
# checking for rows where there are duplicated column values
df.apply(lambda x : x.duplicated()).any(axis = 1)
# Out:
# 0         False
# 1          True
# 2          True
# 3          True
# 4          True
#           ...
# 550063     True
# 550064     True
# 550065     True
# 550066     True
# 550067     True
# Length: 550068, dtype: bool

# %%
# getting rows where there are duplicated values
df [ df.apply(lambda x : x.duplicated()).any(axis = 1)]
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# 5       1000003  P00193542      M  26-35          15             A
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 1                               2               0                   1
# ...

# %%
#Renaming the column name to lower case
df.columns = map(str.lower,df.columns)
df
# Out:
#         user_id product_id gender    age  occupation city_category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        stay_in_current_city_years  marital_status  product_category_1  \
# 0                               2               0                   3
# ...

# %%
#Removing Redundant Values (user id)
df = df.drop_duplicates(subset='user_id')
df
# Out:
#         user_id product_id gender    age  occupation city_category  \
# 0       1000001  P00069042      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# 5       1000003  P00193542      M  26-35          15             A
# 6       1000004  P00184942      M  46-50           7             B
# 9       1000005  P00274942      M  26-35          20             A
# ...         ...        ...    ...    ...         ...           ...
# 185450  1004588  P00260042      F  26-35           4             C
# 187076  1004871  P00242742      M  18-25          12             C
# 221494  1004113  P00351842      M  36-45          17             C
# 229480  1005391  P00339342      M  26-35           7             A
# 243533  1001529  P00000242      M  18-25           4             C
#
#        stay_in_current_city_years  marital_status  product_category_1  \
# 0                               2               0                   3
# ...

# %%
#Checking for unique values in each individual column of the dataset
df.apply(lambda x:x.unique())
# Out:
# user_id                       [1000001, 1000002, 1000003, 1000004, 1000005, ...
# product_id                    [P00069042, P00285442, P00193542, P00184942, P...
# gender                                                                   [F, M]
# age                              [0-17, 55+, 26-35, 46-50, 51-55, 36-45, 18-25]
# occupation                    [10, 16, 15, 7, 20, 9, 1, 12, 17, 0, 3, 4, 11,...
# city_category                                                         [A, C, B]
# stay_in_current_city_years                                     [2, 4+, 3, 1, 0]
# marital_status                                                           [0, 1]
# product_category_1            [3, 8, 1, 5, 6, 2, 13, 4, 16, 11, 15, 18, 12, ...
# product_category_2            [nan, 2.0, 8.0, 14.0, 5.0, 4.0, 17.0, 6.0, 11....
# product_category_3            [nan, 17.0, 14.0, 16.0, 15.0, 8.0, 3.0, 9.0, 1...
# purchase                      [8370, 7969, 15227, 19215, 7871, 5378, 11788, ...
# dtype: object

# %%
df.nunique()
# Out:
# user_id                       5891
# product_id                    1611
# gender                           2
# age                              7
# occupation                      21
# city_category                    3
# stay_in_current_city_years       5
# marital_status                   2
# product_category_1              18
# product_category_2              17
# product_category_3              15
# purchase                      4133
# dtype: int64

# %%
#replace each range in age coulmn to its coressponding category ex:0-17 ->child ,18-25 ->teenage, 26-50 -> adult , 51-55+ ->old

# %%
#1: get all ranges in the data set
df['age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
# 2: map these ranges
map_object = dict()
map_object['0-17'] = 'child'
map_object['18-25'] = 'teenage'
map_object['26-35'] = 'adult'
map_object['36-45'] = 'adult'
map_object['46-50'] = 'adult'
map_object['51-55'] = 'old'
map_object['55+'] = 'old'
df.loc[:,'age'] = df.loc[:,'age'].replace(map_object)

# %%
df
# Out:
#         user_id product_id gender      age  occupation city_category  \
# 0       1000001  P00069042      F    child          10             A
# 4       1000002  P00285442      M      old          16             C
# 5       1000003  P00193542      M    adult          15             A
# 6       1000004  P00184942      M    adult           7             B
# 9       1000005  P00274942      M    adult          20             A
# ...         ...        ...    ...      ...         ...           ...
# 185450  1004588  P00260042      F    adult           4             C
# 187076  1004871  P00242742      M  teenage          12             C
# 221494  1004113  P00351842      M    adult          17             C
# 229480  1005391  P00339342      M    adult           7             A
# 243533  1001529  P00000242      M  teenage           4             C
#
#        stay_in_current_city_years  marital_status  product_category_1  \
# ...

# %%
#Checking for unique values for city_years column
df['stay_in_current_city_years'].unique()
# Out:
# array(['2', '4+', '3', '1', '0'], dtype=object)

# %%
#remove + from rows in city_years column
df = df.replace({'4+':'4'})
df
# Out:
#         user_id product_id gender      age  occupation city_category  \
# 0       1000001  P00069042      F    child          10             A
# 4       1000002  P00285442      M      old          16             C
# 5       1000003  P00193542      M    adult          15             A
# 6       1000004  P00184942      M    adult           7             B
# 9       1000005  P00274942      M    adult          20             A
# ...         ...        ...    ...      ...         ...           ...
# 185450  1004588  P00260042      F    adult           4             C
# 187076  1004871  P00242742      M  teenage          12             C
# 221494  1004113  P00351842      M    adult          17             C
# 229480  1005391  P00339342      M    adult           7             A
# 243533  1001529  P00000242      M  teenage           4             C
#
#        stay_in_current_city_years  marital_status  product_category_1  \
# ...

# %%
#Checking for unique values for category_1 column
df['product_category_1'].unique()
# Out:
# array([ 3,  8,  1,  5,  6,  2, 13,  4, 16, 11, 15, 18, 12, 10,  7, 14,  9,
#        17], dtype=int64)

# %%
#Checking for unique values for category_2 column
df['product_category_2'].unique()
# Out:
# array([nan,  2.,  8., 14.,  5.,  4., 17.,  6., 11., 12., 16., 15., 10.,
#         9.,  3., 13., 18.,  7.])

# %%
#fill null you found
df['product_category_2'] = df['product_category_2'].fillna('none')
df
# Out:
#         user_id product_id gender      age  occupation city_category  \
# 0       1000001  P00069042      F    child          10             A
# 4       1000002  P00285442      M      old          16             C
# 5       1000003  P00193542      M    adult          15             A
# 6       1000004  P00184942      M    adult           7             B
# 9       1000005  P00274942      M    adult          20             A
# ...         ...        ...    ...      ...         ...           ...
# 185450  1004588  P00260042      F    adult           4             C
# 187076  1004871  P00242742      M  teenage          12             C
# 221494  1004113  P00351842      M    adult          17             C
# 229480  1005391  P00339342      M    adult           7             A
# 243533  1001529  P00000242      M  teenage           4             C
#
#        stay_in_current_city_years  marital_status  product_category_1  \
# ...

# %%
#Checking for unique values for category_3 column
df['product_category_3'].unique()
# Out:
# array([nan, 17., 14., 16., 15.,  8.,  3.,  9., 18.,  5., 13.,  6., 12.,
#        10., 11.,  4.])

# %%
#fill null you found
df['product_category_3'] = df['product_category_3'].fillna('none')
df
# Out:
#         user_id product_id gender      age  occupation city_category  \
# 0       1000001  P00069042      F    child          10             A
# 4       1000002  P00285442      M      old          16             C
# 5       1000003  P00193542      M    adult          15             A
# 6       1000004  P00184942      M    adult           7             B
# 9       1000005  P00274942      M    adult          20             A
# ...         ...        ...    ...      ...         ...           ...
# 185450  1004588  P00260042      F    adult           4             C
# 187076  1004871  P00242742      M  teenage          12             C
# 221494  1004113  P00351842      M    adult          17             C
# 229480  1005391  P00339342      M    adult           7             A
# 243533  1001529  P00000242      M  teenage           4             C
#
#        stay_in_current_city_years  marital_status  product_category_1  \
# ...

# %%
#check for null values
df.isnull().any()
# Out:
# user_id                       False
# product_id                    False
# gender                        False
# age                           False
# occupation                    False
# city_category                 False
# stay_in_current_city_years    False
# marital_status                False
# product_category_1            False
# product_category_2            False
# product_category_3            False
# purchase                      False
# dtype: bool

# %%
#check for duplicates values
# 1:rows
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [user_id, product_id, gender, age, occupation, city_category, stay_in_current_city_years, marital_status, product_category_1, product_category_2, product_category_3, purchase]
# Index: []

# %%
# 2:columns
df.apply(lambda x : x.duplicated())
# Out:
#         user_id  product_id  gender    age  occupation  city_category  \
# 0         False       False   False  False       False          False
# 4         False       False   False  False       False          False
# 5         False       False    True  False       False           True
# 6         False       False    True   True       False          False
# 9         False       False    True   True       False           True
# ...         ...         ...     ...    ...         ...            ...
# 185450    False        True    True   True        True           True
# 187076    False        True    True   True        True           True
# 221494    False        True    True   True        True           True
# 229480    False        True    True   True        True           True
# 243533    False       False    True   True        True           True
#
#         stay_in_current_city_years  marital_status  product_category_1  \
# ...
