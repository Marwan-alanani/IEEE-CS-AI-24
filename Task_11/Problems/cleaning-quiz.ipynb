# %% [markdown]
# # Cleaning Practice
# Let's first practice handling missing values and duplicate data using the `cancer_data_means.csv` file.

# %%
#import libraries and assign cancer_data_means.csv to a variable 
import pandas as pd
df = pd.read_csv("cancer_data_means.csv",index_col = 'id')
df
# Out:
#          diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# id
# 842302           M        17.99           NaN          122.80     1001.0
# 842517           M        20.57         17.77          132.90     1326.0
# 84300903         M        19.69         21.25          130.00     1203.0
# 84348301         M        11.42         20.38           77.58      386.1
# 84358402         M        20.29         14.34          135.10     1297.0
# ...            ...          ...           ...             ...        ...
# 926424           M        21.56         22.39          142.00     1479.0
# 926682           M        20.13         28.25          131.20     1261.0
# 926954           M        16.60         28.08          108.30      858.1
# 927241           M        20.60         29.33          140.10     1265.0
# 92751            B         7.76         24.54           47.92      181.0
#
#           smoothness_mean  compactness_mean  concavity_mean  \
# id
# 842302            0.11840           0.27760         0.30010
# 842517            0.08474           0.07864         0.08690
# 84300903          0.10960           0.15990         0.19740
# 84348301              NaN           0.28390         0.24140
# 84358402          0.10030           0.13280         0.19800
# ...                   ...               ...             ...
# 926424            0.11100           0.11590         0.24390
# 926682            0.09780           0.10340         0.14400
# 926954            0.08455           0.10230         0.09251
# 927241            0.11780           0.27700         0.35140
# 92751             0.05263           0.04362         0.00000
#
#           concave_points_mean  symmetry_mean  fractal_dimension_mean
# id
# 842302                0.14710         0.2419                 0.07871
# 842517                0.07017         0.1812                 0.05667
# 84300903              0.12790         0.2069                 0.05999
# 84348301              0.10520         0.2597                 0.09744
# 84358402              0.10430         0.1809                 0.05883
# ...                       ...            ...                     ...
# 926424                0.13890         0.1726                 0.05623
# 926682                0.09791         0.1752                 0.05533
# 926954                0.05302         0.1590                 0.05648
# 927241                0.15200         0.2397                 0.07016
# 92751                 0.00000         0.1587                 0.05884
#
# [569 rows x 11 columns]

# %%
# check which columns have missing values
df.isna().any()
# Out:
# diagnosis                 False
# radius_mean               False
# texture_mean               True
# perimeter_mean            False
# area_mean                 False
# smoothness_mean            True
# compactness_mean          False
# concavity_mean            False
# concave_points_mean       False
# symmetry_mean              True
# fractal_dimension_mean    False
# dtype: bool

# %%
# confirm your correction
df = df.dropna(axis = 1)
df
# texture mean, smoothness mean, and symmetry mean will be removed
# Out:
#          diagnosis  radius_mean  perimeter_mean  area_mean  compactness_mean  \
# id
# 842302           M        17.99          122.80     1001.0           0.27760
# 842517           M        20.57          132.90     1326.0           0.07864
# 84300903         M        19.69          130.00     1203.0           0.15990
# 84348301         M        11.42           77.58      386.1           0.28390
# 84358402         M        20.29          135.10     1297.0           0.13280
# ...            ...          ...             ...        ...               ...
# 926424           M        21.56          142.00     1479.0           0.11590
# 926682           M        20.13          131.20     1261.0           0.10340
# 926954           M        16.60          108.30      858.1           0.10230
# 927241           M        20.60          140.10     1265.0           0.27700
# 92751            B         7.76           47.92      181.0           0.04362
#
#           concavity_mean  concave_points_mean  fractal_dimension_mean
# id
# 842302           0.30010              0.14710                 0.07871
# 842517           0.08690              0.07017                 0.05667
# 84300903         0.19740              0.12790                 0.05999
# 84348301         0.24140              0.10520                 0.09744
# 84358402         0.19800              0.10430                 0.05883
# ...                  ...                  ...                     ...
# 926424           0.24390              0.13890                 0.05623
# 926682           0.14400              0.09791                 0.05533
# 926954           0.09251              0.05302                 0.05648
# 927241           0.35140              0.15200                 0.07016
# 92751            0.00000              0.00000                 0.05884
#
# [569 rows x 8 columns]

# %%
# how many duplicates are there ?
len(df[df.duplicated()])
# Out:
# 7

# %%
# drop duplicates
df = df.drop_duplicates()
df
# Out:
#          diagnosis  radius_mean  perimeter_mean  area_mean  compactness_mean  \
# id
# 842302           M        17.99          122.80     1001.0           0.27760
# 842517           M        20.57          132.90     1326.0           0.07864
# 84300903         M        19.69          130.00     1203.0           0.15990
# 84348301         M        11.42           77.58      386.1           0.28390
# 84358402         M        20.29          135.10     1297.0           0.13280
# ...            ...          ...             ...        ...               ...
# 926424           M        21.56          142.00     1479.0           0.11590
# 926682           M        20.13          131.20     1261.0           0.10340
# 926954           M        16.60          108.30      858.1           0.10230
# 927241           M        20.60          140.10     1265.0           0.27700
# 92751            B         7.76           47.92      181.0           0.04362
#
#           concavity_mean  concave_points_mean  fractal_dimension_mean
# id
# 842302           0.30010              0.14710                 0.07871
# 842517           0.08690              0.07017                 0.05667
# 84300903         0.19740              0.12790                 0.05999
# 84348301         0.24140              0.10520                 0.09744
# 84358402         0.19800              0.10430                 0.05883
# ...                  ...                  ...                     ...
# 926424           0.24390              0.13890                 0.05623
# 926682           0.14400              0.09791                 0.05533
# 926954           0.09251              0.05302                 0.05648
# 927241           0.35140              0.15200                 0.07016
# 92751            0.00000              0.00000                 0.05884
#
# [562 rows x 8 columns]

# %%
# confirm correction by rechecking for duplicates in the data
len(df[df.duplicated()])
# Out:
# 0

# %% [markdown]
# ## Renaming Columns
# Since we also previously changed our dataset to only include means of tumor features, the "_mean" at the end of each feature seems unnecessary. It just takes extra time to type in our analysis later. Rename the columns of the dataframe to remove "_mean".

# %%
# rename the columns of the dataframe (remove _mean from the name of each column if found)
df.columns = df.columns.str.replace('_mean','')
df.columns
# Out:
# Index(['diagnosis', 'radius', 'perimeter', 'area', 'compactness', 'concavity',
#        'concave_points', 'fractal_dimension'],
#       dtype='object')

# %%
# display first few rows of the dataframe to confirm changes
df.head(3)
# Out:
#          diagnosis  radius  perimeter    area  compactness  concavity  \
# id
# 842302           M   17.99      122.8  1001.0      0.27760     0.3001
# 842517           M   20.57      132.9  1326.0      0.07864     0.0869
# 84300903         M   19.69      130.0  1203.0      0.15990     0.1974
#
#           concave_points  fractal_dimension
# id
# 842302           0.14710            0.07871
# 842517           0.07017            0.05667
# 84300903         0.12790            0.05999

# %%
# save this for later as a csv file named "cancer_data_edited.csv" and set indexing to false (why ??)
df.to_csv('cancer_data_edited.csv',index =False)
# index is equal to false so that reading from the edited data will create a new index that is properly ordered
